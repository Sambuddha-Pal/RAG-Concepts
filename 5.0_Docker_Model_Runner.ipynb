# %%
from langchain_openai import ChatOpenAI

# %%
llm=ChatOpenAI(base_url="http://localhost:12434/engines/llama.cpp/v1", model="ai/smolvlm:500M-Q8_0", temperature=0)

# %%
response=llm.invoke("What is Microsoft Fabric?")
response.content
# Out:
# ' Microsoft Fabric is a platform for building and deploying applications and services. It is a cloud-based platform that allows developers to create and manage applications and services using a variety of programming languages and frameworks. Microsoft Fabric is designed to be easy to use and maintain, and it provides a wide range of features for developers to create and deploy applications and services.'
